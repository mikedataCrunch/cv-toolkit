# %% [markdown]
# # Data Exploration

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import sys

# toolkit packages
from cvtoolkit import explore


ROOT = "/home/mdorosan/2023/cv-toolkit/"
META_PATH = os.path.join(ROOT, "metadata/kvasir-capsule.csv")
IMG_ROOT = os.path.join(ROOT, "datasets/kvasir-capsule")

# %% [markdown]
# ## Inspect metadata

# %%
meta = pd.read_csv(META_PATH, sep=";")

# %%
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47248 entries, 0 to 47247
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   filename          47248 non-null  object
#  1   video_id          47248 non-null  object
#  2   frame_number      47248 non-null  int64
#  3   finding_category  47248 non-null  object
#  4   finding_class     47248 non-null  object
#  5   x1                4235 non-null   float64
#  6   y1                4235 non-null   float64
#  7   x2                4235 non-null   float64
#  8   y2                4235 non-null   float64
#  9   x3                4235 non-null   float64
#  10  y3                4235 non-null   float64
#  11  x4                4235 non-null   float64
#  12  y4                4235 non-null   float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 4.7+ MB

# %%
meta.finding_category.unique() # higher level classes
# Out:
# array(['Luminal', 'Anatomy'], dtype=object)

# %%
meta.finding_class.unique() # unique classes
# Out:
# array(['Normal clean mucosa', 'Ileocecal valve', 'Pylorus', 'Erosion',
#        'Reduced Mucosal View', 'Angiectasia', 'Ampulla of Vater',
#        'Erythema', 'Blood - fresh', 'Blood - hematin', 'Foreign Body',
#        'Ulcer', 'Polyp', 'Lymphangiectasia'], dtype=object)

# %%
meta.video_id.iloc[0] # inspect first value
# Out:
# '0728084c8da942d9'

# %%
meta.frame_number.iloc[0] # inspect first value
# Out:
# 22803

# %%
meta.filename.iloc[0] # inspect first value
# Out:
# '0728084c8da942d9_22803.jpg'

# %%
# check repeated files : some have multilabels
meta.filename.value_counts()
# Out:
# filename
# eb0203196e284797_1136.jpg     3
# fb86bc87d3874cd7_3660.jpg     3
# eb0203196e284797_1135.jpg     3
# eb0203196e284797_1131.jpg     3
# eb0203196e284797_1130.jpg     3
#                              ..
# 8885668afb844852_24624.jpg    1
# 8885668afb844852_24625.jpg    1
# 8885668afb844852_24626.jpg    1
# 8885668afb844852_24627.jpg    1
# 04a78ef00c5245e0_902.jpg      1
# Name: count, Length: 47229, dtype: int64

# %% [markdown]
# ## Inspect images

# %%
# random samples
explore.inspect_samples(IMG_ROOT)

# %%
# subset of classes
classes = [
    'Reduced mucosal view', 'Ampulla of vater', 
    'Blood - hematin', 'Blood - fresh'
]
explore.inspect_samples(IMG_ROOT, classes=classes)

# %%
# all classes
explore.inspect_samples(IMG_ROOT, classes='all')

# %% [markdown]
# ## End.
